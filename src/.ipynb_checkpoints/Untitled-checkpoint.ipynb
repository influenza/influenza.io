# %%
pip install geobr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geobr
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
mun = geobr.read_municipality(code_muni = "RJ", year = 2010)
mun
# Out:
# C:\Users\gabri\miniconda3\Lib\site-packages\geopandas\array.py:93: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out
#    code_state abbrev_state      name_state  code_region name_region  \
# 0        33.0           RJ  Rio De Janeiro          3.0     Sudeste
#
#                                             geometry
# 0  MULTIPOLYGON (((-41.85946 -20.76517, -41.85748...

# %%
def state():
    mun=geobr.read_municipal_seat(year = 2010)
    mun mun[mun["name_muni"] == "São Paulo"]
    fig, ax = plt.subplots(figsize=(15, 15), dpi=300)
    mun.plot(facecolor="red", edgecolor="#FEBF57", ax=ax)
    ax.set_title("States", fontsize=20)
    plt.savefig("mapamun.png",dpi=200) 
    ax.axis("off")
state()

# %%
def state():
    mun = geobr.read_municipality(code_muni="RJ")
    fig, ax = plt.subplots(figsize=(15, 15), dpi=300)
    mun.plot(facecolor="red", edgecolor="#FEBF57", ax=ax)
    ax.set_title("States", fontsize=20)
    plt.savefig("mapamun.png",dpi=200) 
    ax.axis("off")
state()
# Out:
# C:\Users\gabri\miniconda3\Lib\site-packages\geopandas\plotting.py:33: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# C:\Users\gabri\miniconda3\Lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
def Pais():
    states = geobr.read_state(year=2019)
    fig, ax = plt.subplots(figsize=(15, 15), dpi=300)
    states.plot(facecolor="red", edgecolor="#FEBF57", ax=ax)
    ax.set_title("States", fontsize=20)
    plt.savefig("mapaci.png",dpi=200) 
    ax.axis("off")
Pais()
# Out:
# C:\Users\gabri\miniconda3\Lib\site-packages\geopandas\plotting.py:33: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# C:\Users\gabri\miniconda3\Lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# C:\Users\gabri\miniconda3\Lib\site-packages\descartes\patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
